# %%
x = [1,2,3,4]
x
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# # You can explain solutions here

# %%
x = [1,2,3,4]
x
# Out:
# [1, 2, 3, 4]

# %%
z = 100

# %%
print(z)
# Out:
# 100

# %%
16 / 3
# Out:
# 5.333333333333333
